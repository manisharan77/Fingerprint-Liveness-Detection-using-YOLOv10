# %%
from ultralytics import YOLO
import cv2
import os
from pathlib import Path
from PIL import Image

# %%
model= YOLO('yolov10n.pt')

# %%
model.train(
    data=r'C:\Final_project\VTPDL22\VTPDL22\Code\data.yaml',
    epochs=20,

    batch=16,
    cache=False,
)
# Out:
# Ultralytics 8.4.21  Python-3.13.9 torch-2.10.0+cpu CPU (12th Gen Intel Core i5-12450H)
# ...
