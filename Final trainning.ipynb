# %%
from ultralytics import YOLO
import cv2
import os
from pathlib import Path
from PIL import Image

# %%
model= YOLO('yolov10n.pt')

# %%
model.train(
    data='F:/Mjaor_2025/Extra Projects/DL22/data.yaml',
    epochs=20

    batch=16,
    cache=False,
)
# Out:
#   Input In [3]
#     batch=16,
#     ^
# SyntaxError: invalid syntax
